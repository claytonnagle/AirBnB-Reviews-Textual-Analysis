# %%
import pandas as pd

# %% [markdown]
# # Preprocessing

# %%
sd_listings_df = pd.read_csv('sandiego_listings.csv')
sd_listings_df
# Out:
#             id                            listing_url       scrape_id  \
# 0         5570      https://www.airbnb.com/rooms/5570  20210317194010
# 1        29967     https://www.airbnb.com/rooms/29967  20210317194010
# 2        38245     https://www.airbnb.com/rooms/38245  20210317194010
# 3        62274     https://www.airbnb.com/rooms/62274  20210317194010
# 4        62949     https://www.airbnb.com/rooms/62949  20210317194010
# ...        ...                                    ...             ...
# 9265  48699191  https://www.airbnb.com/rooms/48699191  20210317194010
# 9266  48701703  https://www.airbnb.com/rooms/48701703  20210317194010
# 9267  48702258  https://www.airbnb.com/rooms/48702258  20210317194010
# 9268  48703115  https://www.airbnb.com/rooms/48703115  20210317194010
# 9269  48708350  https://www.airbnb.com/rooms/48708350  20210317194010
#
#      last_scraped                                               name  \
# 0      2021-03-19                      Ocean front condo on the sand
# 1      2021-03-19                   Great home, 10 min walk to Beach
# 2      2021-03-22                         Point Loma: Den downstairs
# 3      2021-03-20                 charming, colorful, close to beach
# 4      2021-04-03  Pacific Beach Cozy Private Hideaway Bikes Incl...
# ...           ...                                                ...
# 9265   2021-03-20   Pool House! Large Families- Air hockey, foosball
# 9266   2021-03-22  Beach Haven by 710 Vacation Rentals | Bayfront...
# 9267   2021-03-22            Bedroom and Bath near Beaches and Lakes
# 9268   2021-03-20                                    Cozy Condo Room
# 9269   2021-03-22                                SD Luxury apartment
#
#                                             description  \
# 0     Missionbeachretreat.   Great Ocean Front Condo...
# 1     This 2 bedroom, 2 full bathroom home offers al...
# 2     Stay in a 1928 Spanish Style home.  Den is dow...
# 3     Modern, cozy, artsy, and european in a lush ga...
# 4     Wonderful Cozy Private Retreat. Included are u...
# ...                                                 ...
# 9265  Have fun and relax with your family while enjo...
# 9266  Light and bright, this beautiful Beach Haven i...
# 9267  14 miles to nearest beach, other beaches near....
# 9268  The condo is in a great location and very cent...
# 9269                                                NaN
#
#                                   neighborhood_overview  \
# 0     While some may compare San Diego’s Mission Bea...
# 1                                                   NaN
# 2     This neighborhood is an expensive, high-end Po...
# 3     We are in walking distance to Starbucks, Trade...
# 4     This is the best part of Pacific Beach, we are...
# ...                                                 ...
# 9265                                                NaN
# 9266                                      North Mission
# 9267  This home is in a community surrounded by a go...
# 9268                                                NaN
# 9269                                                NaN
#
#                                             picture_url    host_id  \
# 0     https://a0.muscache.com/pictures/d3342744-140a...       8435
# 1     https://a0.muscache.com/pictures/76103867/c9b5...     129123
# 2     https://a0.muscache.com/pictures/f3073822-e493...     164137
# 3     https://a0.muscache.com/pictures/84577734/93ca...     302986
# 4     https://a0.muscache.com/pictures/f5d54435-d02a...      21532
# ...                                                 ...        ...
# 9265  https://a0.muscache.com/pictures/547dfe25-1e04...   25368470
# 9266  https://a0.muscache.com/pictures/7404d1da-64ee...   88168913
# 9267  https://a0.muscache.com/pictures/60745ef9-1ff8...  392915024
# 9268  https://a0.muscache.com/pictures/miso/Hosting-...    7810506
# 9269  https://a0.muscache.com/pictures/811a65fd-6e04...  108499993
#
#                                          host_url  ...  \
# 0          https://www.airbnb.com/users/show/8435  ...
# 1        https://www.airbnb.com/users/show/129123  ...
# 2        https://www.airbnb.com/users/show/164137  ...
# 3        https://www.airbnb.com/users/show/302986  ...
# 4         https://www.airbnb.com/users/show/21532  ...
# ...                                           ...  ...
# 9265   https://www.airbnb.com/users/show/25368470  ...
# 9266   https://www.airbnb.com/users/show/88168913  ...
# 9267  https://www.airbnb.com/users/show/392915024  ...
# 9268    https://www.airbnb.com/users/show/7810506  ...
# 9269  https://www.airbnb.com/users/show/108499993  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 0                            NaN                    NaN                 NaN
# 1                           10.0                   10.0                10.0
# 2                           10.0                    9.0                 9.0
# 3                           10.0                   10.0                10.0
# 4                           10.0                   10.0                10.0
# ...                          ...                    ...                 ...
# 9265                         NaN                    NaN                 NaN
# 9266                         NaN                    NaN                 NaN
# 9267                         NaN                    NaN                 NaN
# 9268                         NaN                    NaN                 NaN
# 9269                         NaN                    NaN                 NaN
#
#      license instant_bookable calculated_host_listings_count  \
# 0        NaN                f                              3
# 1        NaN                f                              5
# 2        NaN                f                              3
# 3        NaN                f                              2
# 4        NaN                f                              2
# ...      ...              ...                            ...
# 9265     NaN                f                              4
# 9266     NaN                f                            166
# 9267     NaN                t                              1
# 9268     NaN                f                              1
# 9269     NaN                f                              1
#
#      calculated_host_listings_count_entire_homes  \
# 0                                              3
# 1                                              5
# 2                                              0
# 3                                              2
# 4                                              2
# ...                                          ...
# 9265                                           4
# 9266                                         166
# 9267                                           0
# 9268                                           0
# 9269                                           1
#
#      calculated_host_listings_count_private_rooms  \
# 0                                               0
# 1                                               0
# 2                                               3
# 3                                               0
# 4                                               0
# ...                                           ...
# 9265                                            0
# 9266                                            0
# 9267                                            1
# 9268                                            1
# 9269                                            0
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                              0               NaN
# 1                                              0              0.48
# 2                                              0              1.11
# 3                                              0              5.05
# 4                                              0              7.17
# ...                                          ...               ...
# 9265                                           0               NaN
# 9266                                           0               NaN
# 9267                                           0               NaN
# 9268                                           0               NaN
# 9269                                           0               NaN
#
# [9270 rows x 74 columns]

# %%
sandiego_senti_df = pd.read_csv('separated_sentiment.csv')
sandiego_senti_df
# Out:
#         Unnamed: 0  listing_id         id        date  reviewer_id  \
# 0                0       38245      93702  2010-09-09       187475
# 1                1       38245     132608  2010-11-02       269362
# 2                2       38245     142704  2010-11-22       108540
# 3                3       38245     156426  2010-12-20       314129
# 4                4       38245     169467  2011-01-11        25218
# ...            ...         ...        ...         ...          ...
# 288419      288419    43791368  735972757  2021-03-02     61179908
# 288420      288420    43791368  736287480  2021-03-04     56385941
# 288421      288421    43791368  736545734  2021-03-05    152317017
# 288422      288422    43791368  739226692  2021-03-14    182841943
# 288423      288423    43791368  739928005  2021-03-17    392173895
#
#        reviewer_name                                           comments  \
# 0            William  really great hist and nice place, a good locat...
# 1               John  Melinda is a god person to deal with and very ...
# 2              Suzan  Melinda's house in a beautiful part of San Die...
# 3              Sonia  My stay at Melinda's was great. Such a nice, w...
# 4              David  Melinda is a very friendly host who is attenti...
# ...              ...                                                ...
# 288419          Chaz  Great place to stay and only about a 5 minute ...
# 288420        Justin  Great spot. Exactly how described. Perfect for...
# 288421       Cameron  The place was in a good location right downtow...
# 288422         Gulya                              A nice place to stay!
# 288423        Alyssa  I would definitely never book with this host.\...
#
#                                          comments cleaned  \
# 0       realli great hist nice place good locat san di...
# 1       melinda god person deal accommodatingeasi go h...
# 2       melinda hous beauti part san diego close airpo...
# 3       stay melinda great nice warm person beauti com...
# 4       melinda friendli host attent guest even invit ...
# ...                                                   ...
# 288419  great place stay 5 minut drive airport car ren...
# 288420      great spot exactli describ perfect quick trip
# 288421  place good locat right downtown view bay one t...
# 288422                                    nice place stay
# 288423  would definit never book host unprofession sen...
#
#                                                    tokens  \
# 0       ['realli', 'great', 'hist', 'nice', 'place', '...
# 1       ['melinda', 'god', 'person', 'deal', 'accommod...
# 2       ['melinda', 'hous', 'beauti', 'part', 'san', '...
# 3       ['stay', 'melinda', 'great', 'nice', 'warm', '...
# 4       ['melinda', 'friendli', 'host', 'attent', 'gue...
# ...                                                   ...
# 288419  ['great', 'place', 'stay', '5', 'minut', 'driv...
# 288420  ['great', 'spot', 'exactli', 'describ', 'perfe...
# 288421  ['place', 'good', 'locat', 'right', 'downtown'...
# 288422                          ['nice', 'place', 'stay']
# 288423  ['would', 'definit', 'never', 'book', 'host', ...
#
#                                                     senti  Sentiment  \
# 0       Sentiment(polarity=0.3726190476190476, subject...   0.372619
# 1               Sentiment(polarity=0.0, subjectivity=0.2)   0.000000
# 2       Sentiment(polarity=0.2285714285714286, subject...   0.228571
# 3       Sentiment(polarity=0.5393939393939394, subject...   0.539394
# 4             Sentiment(polarity=0.05, subjectivity=0.25)   0.050000
# ...                                                   ...        ...
# 288419  Sentiment(polarity=0.35000000000000003, subjec...   0.350000
# 288420  Sentiment(polarity=0.7111111111111111, subject...   0.711111
# 288421  Sentiment(polarity=0.43605442176870746, subjec...   0.436054
# 288422          Sentiment(polarity=0.6, subjectivity=1.0)   0.600000
# 288423       Sentiment(polarity=-0.15, subjectivity=0.65)  -0.150000
#
#         Subjectivity
# 0           0.686607
# 1           0.200000
# 2           0.295238
# 3           0.709091
# 4           0.250000
# ...              ...
# 288419      0.425000
# 288420      0.750000
# 288421      0.508673
# 288422      1.000000
# 288423      0.650000
#
# [288424 rows x 12 columns]

# %%
# drop column id 
clean_sandiego_senti_df = sandiego_senti_df.drop(columns=['id'])
# clean_sandiego_senti_df

# %%
join_df = sd_listings_df.join(clean_sandiego_senti_df.set_index('listing_id'), on='id')
join_df
# Out:
#             id                            listing_url       scrape_id  \
# 0         5570      https://www.airbnb.com/rooms/5570  20210317194010
# 1        29967     https://www.airbnb.com/rooms/29967  20210317194010
# 2        38245     https://www.airbnb.com/rooms/38245  20210317194010
# 2        38245     https://www.airbnb.com/rooms/38245  20210317194010
# 2        38245     https://www.airbnb.com/rooms/38245  20210317194010
# ...        ...                                    ...             ...
# 9265  48699191  https://www.airbnb.com/rooms/48699191  20210317194010
# 9266  48701703  https://www.airbnb.com/rooms/48701703  20210317194010
# 9267  48702258  https://www.airbnb.com/rooms/48702258  20210317194010
# 9268  48703115  https://www.airbnb.com/rooms/48703115  20210317194010
# 9269  48708350  https://www.airbnb.com/rooms/48708350  20210317194010
#
#      last_scraped                                               name  \
# 0      2021-03-19                      Ocean front condo on the sand
# 1      2021-03-19                   Great home, 10 min walk to Beach
# 2      2021-03-22                         Point Loma: Den downstairs
# 2      2021-03-22                         Point Loma: Den downstairs
# 2      2021-03-22                         Point Loma: Den downstairs
# ...           ...                                                ...
# 9265   2021-03-20   Pool House! Large Families- Air hockey, foosball
# 9266   2021-03-22  Beach Haven by 710 Vacation Rentals | Bayfront...
# 9267   2021-03-22            Bedroom and Bath near Beaches and Lakes
# 9268   2021-03-20                                    Cozy Condo Room
# 9269   2021-03-22                                SD Luxury apartment
#
#                                             description  \
# 0     Missionbeachretreat.   Great Ocean Front Condo...
# 1     This 2 bedroom, 2 full bathroom home offers al...
# 2     Stay in a 1928 Spanish Style home.  Den is dow...
# 2     Stay in a 1928 Spanish Style home.  Den is dow...
# 2     Stay in a 1928 Spanish Style home.  Den is dow...
# ...                                                 ...
# 9265  Have fun and relax with your family while enjo...
# 9266  Light and bright, this beautiful Beach Haven i...
# 9267  14 miles to nearest beach, other beaches near....
# 9268  The condo is in a great location and very cent...
# 9269                                                NaN
#
#                                   neighborhood_overview  \
# 0     While some may compare San Diego’s Mission Bea...
# 1                                                   NaN
# 2     This neighborhood is an expensive, high-end Po...
# 2     This neighborhood is an expensive, high-end Po...
# 2     This neighborhood is an expensive, high-end Po...
# ...                                                 ...
# 9265                                                NaN
# 9266                                      North Mission
# 9267  This home is in a community surrounded by a go...
# 9268                                                NaN
# 9269                                                NaN
#
#                                             picture_url    host_id  \
# 0     https://a0.muscache.com/pictures/d3342744-140a...       8435
# 1     https://a0.muscache.com/pictures/76103867/c9b5...     129123
# 2     https://a0.muscache.com/pictures/f3073822-e493...     164137
# 2     https://a0.muscache.com/pictures/f3073822-e493...     164137
# 2     https://a0.muscache.com/pictures/f3073822-e493...     164137
# ...                                                 ...        ...
# 9265  https://a0.muscache.com/pictures/547dfe25-1e04...   25368470
# 9266  https://a0.muscache.com/pictures/7404d1da-64ee...   88168913
# 9267  https://a0.muscache.com/pictures/60745ef9-1ff8...  392915024
# 9268  https://a0.muscache.com/pictures/miso/Hosting-...    7810506
# 9269  https://a0.muscache.com/pictures/811a65fd-6e04...  108499993
#
#                                          host_url  ... Unnamed: 0        date  \
# 0          https://www.airbnb.com/users/show/8435  ...        NaN         NaN
# 1        https://www.airbnb.com/users/show/129123  ...        NaN         NaN
# 2        https://www.airbnb.com/users/show/164137  ...        0.0  2010-09-09
# 2        https://www.airbnb.com/users/show/164137  ...        1.0  2010-11-02
# 2        https://www.airbnb.com/users/show/164137  ...        2.0  2010-11-22
# ...                                           ...  ...        ...         ...
# 9265   https://www.airbnb.com/users/show/25368470  ...        NaN         NaN
# 9266   https://www.airbnb.com/users/show/88168913  ...        NaN         NaN
# 9267  https://www.airbnb.com/users/show/392915024  ...        NaN         NaN
# 9268    https://www.airbnb.com/users/show/7810506  ...        NaN         NaN
# 9269  https://www.airbnb.com/users/show/108499993  ...        NaN         NaN
#
#      reviewer_id reviewer_name  \
# 0            NaN           NaN
# 1            NaN           NaN
# 2       187475.0       William
# 2       269362.0          John
# 2       108540.0         Suzan
# ...          ...           ...
# 9265         NaN           NaN
# 9266         NaN           NaN
# 9267         NaN           NaN
# 9268         NaN           NaN
# 9269         NaN           NaN
#
#                                                comments  \
# 0                                                   NaN
# 1                                                   NaN
# 2     really great hist and nice place, a good locat...
# 2     Melinda is a god person to deal with and very ...
# 2     Melinda's house in a beautiful part of San Die...
# ...                                                 ...
# 9265                                                NaN
# 9266                                                NaN
# 9267                                                NaN
# 9268                                                NaN
# 9269                                                NaN
#
#                                        comments cleaned  \
# 0                                                   NaN
# 1                                                   NaN
# 2     realli great hist nice place good locat san di...
# 2     melinda god person deal accommodatingeasi go h...
# 2     melinda hous beauti part san diego close airpo...
# ...                                                 ...
# 9265                                                NaN
# 9266                                                NaN
# 9267                                                NaN
# 9268                                                NaN
# 9269                                                NaN
#
#                                                  tokens  \
# 0                                                   NaN
# 1                                                   NaN
# 2     ['realli', 'great', 'hist', 'nice', 'place', '...
# 2     ['melinda', 'god', 'person', 'deal', 'accommod...
# 2     ['melinda', 'hous', 'beauti', 'part', 'san', '...
# ...                                                 ...
# 9265                                                NaN
# 9266                                                NaN
# 9267                                                NaN
# 9268                                                NaN
# 9269                                                NaN
#
#                                                   senti Sentiment Subjectivity
# 0                                                   NaN       NaN          NaN
# 1                                                   NaN       NaN          NaN
# 2     Sentiment(polarity=0.3726190476190476, subject...  0.372619     0.686607
# 2             Sentiment(polarity=0.0, subjectivity=0.2)  0.000000     0.200000
# 2     Sentiment(polarity=0.2285714285714286, subject...  0.228571     0.295238
# ...                                                 ...       ...          ...
# 9265                                                NaN       NaN          NaN
# 9266                                                NaN       NaN          NaN
# 9267                                                NaN       NaN          NaN
# 9268                                                NaN       NaN          NaN
# 9269                                                NaN       NaN          NaN
#
# [296210 rows x 84 columns]

# %%
join_df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'Unnamed: 0', 'date', 'reviewer_id', 'reviewer_name', 'comments',
#        'comments cleaned', 'tokens', 'senti', 'Sentiment', 'Subjectivity'],
#       dtype='object')

# %%
new_df = join_df[['id','review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin',
                  'review_scores_communication','review_scores_location','review_scores_value','latitude','longitude']]
new_df
# Out:
#             id  review_scores_rating  review_scores_accuracy  \
# 0         5570                   NaN                     NaN
# 1        29967                  98.0                    10.0
# 2        38245                  86.0                     9.0
# 2        38245                  86.0                     9.0
# 2        38245                  86.0                     9.0
# ...        ...                   ...                     ...
# 9265  48699191                   NaN                     NaN
# 9266  48701703                   NaN                     NaN
# 9267  48702258                   NaN                     NaN
# 9268  48703115                   NaN                     NaN
# 9269  48708350                   NaN                     NaN
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                           NaN                    NaN
# 1                          10.0                   10.0
# 2                           9.0                   10.0
# 2                           9.0                   10.0
# 2                           9.0                   10.0
# ...                         ...                    ...
# 9265                        NaN                    NaN
# 9266                        NaN                    NaN
# 9267                        NaN                    NaN
# 9268                        NaN                    NaN
# 9269                        NaN                    NaN
#
#       review_scores_communication  review_scores_location  \
# 0                             NaN                     NaN
# 1                            10.0                    10.0
# 2                            10.0                     9.0
# 2                            10.0                     9.0
# 2                            10.0                     9.0
# ...                           ...                     ...
# 9265                          NaN                     NaN
# 9266                          NaN                     NaN
# 9267                          NaN                     NaN
# 9268                          NaN                     NaN
# 9269                          NaN                     NaN
#
#       review_scores_value  latitude  longitude
# 0                     NaN  32.78430 -117.25258
# 1                    10.0  32.80724 -117.25630
# 2                     9.0  32.74202 -117.21870
# 2                     9.0  32.74202 -117.21870
# 2                     9.0  32.74202 -117.21870
# ...                   ...       ...        ...
# 9265                  NaN  32.60464 -117.03533
# 9266                  NaN  32.78679 -117.25282
# 9267                  NaN  32.64641 -116.96242
# 9268                  NaN  32.80578 -117.12911
# 9269                  NaN  32.74610 -117.14378
#
# [296210 rows x 10 columns]

# %%
drop_df = new_df.dropna()
drop_df
# Out:
#             id  review_scores_rating  review_scores_accuracy  \
# 1        29967                  98.0                    10.0
# 2        38245                  86.0                     9.0
# 2        38245                  86.0                     9.0
# 2        38245                  86.0                     9.0
# 2        38245                  86.0                     9.0
# ...        ...                   ...                     ...
# 9184  48525308                 100.0                    10.0
# 9188  48528974                 100.0                    10.0
# 9192  48547478                  80.0                    10.0
# 9195  48553239                 100.0                    10.0
# 9242  48646506                 100.0                    10.0
#
#       review_scores_cleanliness  review_scores_checkin  \
# 1                          10.0                   10.0
# 2                           9.0                   10.0
# 2                           9.0                   10.0
# 2                           9.0                   10.0
# 2                           9.0                   10.0
# ...                         ...                    ...
# 9184                        8.0                   10.0
# 9188                       10.0                   10.0
# 9192                        8.0                    8.0
# 9195                       10.0                   10.0
# 9242                       10.0                   10.0
#
#       review_scores_communication  review_scores_location  \
# 1                            10.0                    10.0
# 2                            10.0                     9.0
# 2                            10.0                     9.0
# 2                            10.0                     9.0
# 2                            10.0                     9.0
# ...                           ...                     ...
# 9184                         10.0                     8.0
# 9188                         10.0                    10.0
# 9192                          8.0                    10.0
# 9195                         10.0                    10.0
# 9242                         10.0                    10.0
#
#       review_scores_value  latitude  longitude
# 1                    10.0  32.80724 -117.25630
# 2                     9.0  32.74202 -117.21870
# 2                     9.0  32.74202 -117.21870
# 2                     9.0  32.74202 -117.21870
# 2                     9.0  32.74202 -117.21870
# ...                   ...       ...        ...
# 9184                 10.0  32.77042 -117.16711
# 9188                 10.0  32.62424 -116.97472
# 9192                 10.0  32.75789 -117.11602
# 9195                 10.0  32.78344 -117.25225
# 9242                 10.0  32.78289 -117.10930
#
# [286100 rows x 10 columns]

# %%
duplicates_df = drop_df.drop_duplicates()
duplicates_df.head(10)
# Out:
#         id  review_scores_rating  review_scores_accuracy  \
# 1    29967                  98.0                    10.0
# 2    38245                  86.0                     9.0
# 3    62274                  96.0                    10.0
# 4    62949                  97.0                    10.0
# 5    67441                 100.0                    10.0
# 6    75668                  97.0                    10.0
# 7    77785                  95.0                    10.0
# 8    79300                  96.0                    10.0
# 9   103417                  98.0                    10.0
# 10  103720                  99.0                    10.0
#
#     review_scores_cleanliness  review_scores_checkin  \
# 1                        10.0                   10.0
# 2                         9.0                   10.0
# 3                        10.0                   10.0
# 4                        10.0                   10.0
# 5                        10.0                   10.0
# 6                         9.0                   10.0
# 7                        10.0                   10.0
# 8                         9.0                   10.0
# 9                        10.0                   10.0
# 10                       10.0                   10.0
#
#     review_scores_communication  review_scores_location  review_scores_value  \
# 1                          10.0                    10.0                 10.0
# 2                          10.0                     9.0                  9.0
# 3                          10.0                    10.0                 10.0
# 4                          10.0                    10.0                 10.0
# 5                          10.0                    10.0                 10.0
# 6                          10.0                    10.0                 10.0
# 7                          10.0                    10.0                 10.0
# 8                          10.0                    10.0                 10.0
# 9                          10.0                    10.0                 10.0
# 10                         10.0                    10.0                 10.0
#
#     latitude  longitude
# 1   32.80724 -117.25630
# 2   32.74202 -117.21870
# 3   32.80734 -117.24243
# 4   32.80885 -117.23043
# 5   32.76365 -117.07675
# 6   32.74730 -117.14423
# 7   32.74810 -117.19165
# 8   32.74594 -117.14406
# 9   32.81321 -117.26853
# 10  32.74779 -117.16480

# %%
reset_df = duplicates_df.reset_index()
reset_df.head(115)
# Out:
#      index      id  review_scores_rating  review_scores_accuracy  \
# 0        1   29967                  98.0                    10.0
# 1        2   38245                  86.0                     9.0
# 2        3   62274                  96.0                    10.0
# 3        4   62949                  97.0                    10.0
# 4        5   67441                 100.0                    10.0
# ..     ...     ...                   ...                     ...
# 110    111  657126                  98.0                    10.0
# 111    112  670830                  92.0                    10.0
# 112    114  678569                  98.0                    10.0
# 113    115  691132                  89.0                     9.0
# 114    116  691897                  99.0                    10.0
#
#      review_scores_cleanliness  review_scores_checkin  \
# 0                         10.0                   10.0
# 1                          9.0                   10.0
# 2                         10.0                   10.0
# 3                         10.0                   10.0
# 4                         10.0                   10.0
# ..                         ...                    ...
# 110                       10.0                   10.0
# 111                        9.0                   10.0
# 112                       10.0                   10.0
# 113                        9.0                   10.0
# 114                       10.0                   10.0
#
#      review_scores_communication  review_scores_location  review_scores_value  \
# 0                           10.0                    10.0                 10.0
# 1                           10.0                     9.0                  9.0
# 2                           10.0                    10.0                 10.0
# 3                           10.0                    10.0                 10.0
# 4                           10.0                    10.0                 10.0
# ..                           ...                     ...                  ...
# 110                         10.0                    10.0                  9.0
# 111                         10.0                    10.0                  9.0
# 112                         10.0                    10.0                 10.0
# 113                          9.0                    10.0                  9.0
# 114                         10.0                    10.0                  9.0
#
#      latitude  longitude
# 0    32.80724 -117.25630
# 1    32.74202 -117.21870
# 2    32.80734 -117.24243
# 3    32.80885 -117.23043
# 4    32.76365 -117.07675
# ..        ...        ...
# 110  32.84588 -117.27058
# 111  32.72704 -117.16424
# 112  32.84543 -117.26990
# 113  32.80887 -117.25906
# 114  32.71937 -117.22115
#
# [115 rows x 11 columns]

# %%
clean_df = reset_df.drop(columns=['index'])
clean_df.head(114)
# Out:
#          id  review_scores_rating  review_scores_accuracy  \
# 0     29967                  98.0                    10.0
# 1     38245                  86.0                     9.0
# 2     62274                  96.0                    10.0
# 3     62949                  97.0                    10.0
# 4     67441                 100.0                    10.0
# ..      ...                   ...                     ...
# 109  657051                  96.0                    10.0
# 110  657126                  98.0                    10.0
# 111  670830                  92.0                    10.0
# 112  678569                  98.0                    10.0
# 113  691132                  89.0                     9.0
#
#      review_scores_cleanliness  review_scores_checkin  \
# 0                         10.0                   10.0
# 1                          9.0                   10.0
# 2                         10.0                   10.0
# 3                         10.0                   10.0
# 4                         10.0                   10.0
# ..                         ...                    ...
# 109                       10.0                   10.0
# 110                       10.0                   10.0
# 111                        9.0                   10.0
# 112                       10.0                   10.0
# 113                        9.0                   10.0
#
#      review_scores_communication  review_scores_location  review_scores_value  \
# 0                           10.0                    10.0                 10.0
# 1                           10.0                     9.0                  9.0
# 2                           10.0                    10.0                 10.0
# 3                           10.0                    10.0                 10.0
# 4                           10.0                    10.0                 10.0
# ..                           ...                     ...                  ...
# 109                         10.0                    10.0                 10.0
# 110                         10.0                    10.0                  9.0
# 111                         10.0                    10.0                  9.0
# 112                         10.0                    10.0                 10.0
# 113                          9.0                    10.0                  9.0
#
#      latitude  longitude
# 0    32.80724 -117.25630
# 1    32.74202 -117.21870
# 2    32.80734 -117.24243
# 3    32.80885 -117.23043
# 4    32.76365 -117.07675
# ..        ...        ...
# 109  32.72266 -117.12402
# 110  32.84588 -117.27058
# 111  32.72704 -117.16424
# 112  32.84543 -117.26990
# 113  32.80887 -117.25906
#
# [114 rows x 10 columns]

# %%
clean_df.dtypes
# Out:
# id                               int64
# review_scores_rating           float64
# review_scores_accuracy         float64
# review_scores_cleanliness      float64
# review_scores_checkin          float64
# review_scores_communication    float64
# review_scores_location         float64
# review_scores_value            float64
# latitude                       float64
# longitude                      float64
# dtype: object

# %% [markdown]
# #### Averages

# %%
mean_df = sandiego_senti_df.groupby(['listing_id']).mean()
mean_df
# Out:
#             Unnamed: 0            id   reviewer_id  Sentiment  Subjectivity
# listing_id
# 38245             71.0  9.332990e+07  3.155978e+07   0.359868      0.535697
# 62274            458.5  2.125843e+08  5.305670e+07   0.410466      0.573905
# 62949           1150.0  2.780960e+08  8.390608e+07   0.459088      0.615687
# 75668           1623.0  1.358540e+08  4.811615e+07   0.408208      0.579592
# 79300           1799.0  8.452657e+07  3.080475e+07   0.411851      0.577792
# ...                ...           ...           ...        ...           ...
# 42143732      287961.0  6.750451e+08  1.417634e+08   0.397814      0.592205
# 42608887      288066.0  6.696722e+08  1.919387e+08   0.385048      0.605529
# 42627855      288168.5  6.746798e+08  1.857774e+08   0.385375      0.611147
# 42689144      288271.5  6.737881e+08  1.833232e+08   0.425131      0.612388
# 43791368      288373.0  6.945957e+08  1.901561e+08   0.493769      0.657676
#
# [1484 rows x 5 columns]

# %%
# creating list_id as a column
mean_df['senti_mean_id'] = mean_df.index

# %%
senti_avg_df = mean_df[['senti_mean_id','Sentiment','Subjectivity']]
senti_avg_df
# Out:
#             senti_mean_id  Sentiment  Subjectivity
# listing_id
# 38245               38245   0.359868      0.535697
# 62274               62274   0.410466      0.573905
# 62949               62949   0.459088      0.615687
# 75668               75668   0.408208      0.579592
# 79300               79300   0.411851      0.577792
# ...                   ...        ...           ...
# 42143732         42143732   0.397814      0.592205
# 42608887         42608887   0.385048      0.605529
# 42627855         42627855   0.385375      0.611147
# 42689144         42689144   0.425131      0.612388
# 43791368         43791368   0.493769      0.657676
#
# [1484 rows x 3 columns]

# %%
# join_df = sd_listings_df.join(clean_sandiego_senti_df.set_index('listing_id'), on='id')

join_mean_df = clean_df.join(senti_avg_df.set_index('senti_mean_id'), on='id')
join_mean_df
# Out:
#             id  review_scores_rating  review_scores_accuracy  \
# 0        29967                  98.0                    10.0
# 1        38245                  86.0                     9.0
# 2        62274                  96.0                    10.0
# 3        62949                  97.0                    10.0
# 4        67441                 100.0                    10.0
# ...        ...                   ...                     ...
# 7745  48525308                 100.0                    10.0
# 7746  48528974                 100.0                    10.0
# 7747  48547478                  80.0                    10.0
# 7748  48553239                 100.0                    10.0
# 7749  48646506                 100.0                    10.0
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                          10.0                   10.0
# 1                           9.0                   10.0
# 2                          10.0                   10.0
# 3                          10.0                   10.0
# 4                          10.0                   10.0
# ...                         ...                    ...
# 7745                        8.0                   10.0
# 7746                       10.0                   10.0
# 7747                        8.0                    8.0
# 7748                       10.0                   10.0
# 7749                       10.0                   10.0
#
#       review_scores_communication  review_scores_location  \
# 0                            10.0                    10.0
# 1                            10.0                     9.0
# 2                            10.0                    10.0
# 3                            10.0                    10.0
# 4                            10.0                    10.0
# ...                           ...                     ...
# 7745                         10.0                     8.0
# 7746                         10.0                    10.0
# 7747                          8.0                    10.0
# 7748                         10.0                    10.0
# 7749                         10.0                    10.0
#
#       review_scores_value  latitude  longitude  Sentiment  Subjectivity
# 0                    10.0  32.80724 -117.25630        NaN           NaN
# 1                     9.0  32.74202 -117.21870   0.359868      0.535697
# 2                    10.0  32.80734 -117.24243   0.410466      0.573905
# 3                    10.0  32.80885 -117.23043   0.459088      0.615687
# 4                    10.0  32.76365 -117.07675        NaN           NaN
# ...                   ...       ...        ...        ...           ...
# 7745                 10.0  32.77042 -117.16711        NaN           NaN
# 7746                 10.0  32.62424 -116.97472        NaN           NaN
# 7747                 10.0  32.75789 -117.11602        NaN           NaN
# 7748                 10.0  32.78344 -117.25225        NaN           NaN
# 7749                 10.0  32.78289 -117.10930        NaN           NaN
#
# [7750 rows x 12 columns]

# %%
sandiego_df = join_mean_df.dropna()
sandiego_df
# Out:
#             id  review_scores_rating  review_scores_accuracy  \
# 1        38245                  86.0                     9.0
# 2        62274                  96.0                    10.0
# 3        62949                  97.0                    10.0
# 5        75668                  97.0                    10.0
# 7        79300                  96.0                    10.0
# ...        ...                   ...                     ...
# 6185  42143732                 100.0                    10.0
# 6293  42608887                  87.0                     8.0
# 6296  42627855                  87.0                     9.0
# 6308  42689144                  93.0                    10.0
# 6652  43791368                  94.0                     9.0
#
#       review_scores_cleanliness  review_scores_checkin  \
# 1                           9.0                   10.0
# 2                          10.0                   10.0
# 3                          10.0                   10.0
# 5                           9.0                   10.0
# 7                           9.0                   10.0
# ...                         ...                    ...
# 6185                       10.0                   10.0
# 6293                        8.0                    9.0
# 6296                        9.0                   10.0
# 6308                        9.0                   10.0
# 6652                       10.0                   10.0
#
#       review_scores_communication  review_scores_location  \
# 1                            10.0                     9.0
# 2                            10.0                    10.0
# 3                            10.0                    10.0
# 5                            10.0                    10.0
# 7                            10.0                    10.0
# ...                           ...                     ...
# 6185                         10.0                    10.0
# 6293                          9.0                     9.0
# 6296                          9.0                     9.0
# 6308                         10.0                    10.0
# 6652                         10.0                    10.0
#
#       review_scores_value  latitude  longitude  Sentiment  Subjectivity
# 1                     9.0  32.74202 -117.21870   0.359868      0.535697
# 2                    10.0  32.80734 -117.24243   0.410466      0.573905
# 3                    10.0  32.80885 -117.23043   0.459088      0.615687
# 5                    10.0  32.74730 -117.14423   0.408208      0.579592
# 7                    10.0  32.74594 -117.14406   0.411851      0.577792
# ...                   ...       ...        ...        ...           ...
# 6185                 10.0  32.72820 -117.16429   0.397814      0.592205
# 6293                  8.0  32.75358 -117.24758   0.385048      0.605529
# 6296                  8.0  32.75304 -117.24761   0.385375      0.611147
# 6308                  9.0  32.77909 -117.25198   0.425131      0.612388
# 6652                  9.0  32.72814 -117.16591   0.493769      0.657676
#
# [1444 rows x 12 columns]

# %%
# checking above if averages are correct 
# senti_avg_df

# %% [markdown]
# ### Polarity/Review Rating Scatter + Linear Regression

# %%
import matplotlib.pyplot as plt 

plt.scatter(sandiego_df['Sentiment'], sandiego_df['review_scores_rating'])
plt.xlabel('Sentiment Average Score')
plt.ylabel('Review Rating')
# Out:
# Text(0, 0.5, 'Review Rating')

# %%
# reshape 
X = sandiego_df['Sentiment'].values.reshape(-1,1)
y = sandiego_df['review_scores_rating'].values.reshape(-1,1)

print("Shape:",X.shape, y.shape)
# Out:
# Shape: (1444, 1) (1444, 1)

# %%
from sklearn.model_selection import train_test_split 

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression 

model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X, y) # whole data
# Out:
# 0.040218816376581756

# %%
from sklearn.metrics import mean_squared_error, r2_score 

predict = model.predict(X_test)

mse = mean_squared_error(y_test, predict)
r2 = r2_score(y_test, predict)

print(f'Mean Squared Error (MSE): {mse}')
print (f'R-squared (R2): {r2}')
# Out:
# Mean Squared Error (MSE): 7.432739074536826
# R-squared (R2): 0.019035130375057663

# %% [markdown]
# BAD R2 SCORE.. Hard to predict

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, predict, color='red')

# %%
# Model A Bit Off
# Checking Predicted Scores
print(f"True output: {y[0]}")
print(f"Predicted output: {predict[0]}")
print(f"Prediction Error: {predict[0]-y[0]}")
# Out:
# True output: [86.]
# Predicted output: [95.88147855]
# Prediction Error: [9.88147855]

# %%
print(f"True output: {y[1]}")
print(f"Predicted output: {predict[1]}")
print(f"Prediction Error: {predict[1]-y[1]}")
# Out:
# True output: [96.]
# Predicted output: [96.39175043]
# Prediction Error: [0.39175043]

# %%
print(f"True output: {y[2]}")
print(f"Predicted output: {predict[2]}")
print(f"Prediction Error: {predict[2]-y[2]}")
# Out:
# True output: [97.]
# Predicted output: [95.69452332]
# Prediction Error: [-1.30547668]

# %% [markdown]
# ### Subjectivity/Review Rating Scatter + Linear Regression

# %%
plt.scatter(sandiego_df['Subjectivity'], sandiego_df['review_scores_rating'])
plt.xlabel('Subjectivity Score')
plt.ylabel('Review Rating')
# Out:
# Text(0, 0.5, 'Review Rating')

# %%
X_sub = sandiego_df['Subjectivity'].values.reshape(-1,1)

print("Shape:", X_sub.shape, y.shape)
# Out:
# Shape: (1444, 1) (1444, 1)

# %%
model.score(X_sub, y)
# Out:
# -1.1961421190279533

# %%
X_train_sub, X_test_sub, y_train_rev, y_test_rev = train_test_split(X_sub,y, random_state = 42)

# %%
submodel = LinearRegression()

# %%
submodel.fit(X_train_sub, y_train_rev)
# Out:
# LinearRegression()

# %%
subpredict = submodel.predict(X_test_sub)

sub_mse = mean_squared_error(y_test_rev, subpredict)
sub_r2 = r2_score(y_test_rev, subpredict)

print(f'Mean Squared Error (MSE): {sub_mse}')
print (f'R-squared (R2): {sub_r2}')
# Out:
# Mean Squared Error (MSE): 7.563612978354689
# R-squared (R2): 0.00176253399994597

# %%
plt.scatter(X_test_sub, y_test_rev)
plt.plot(X_test_sub, subpredict, color='red')
plt.xlabel('Subjectivity Score')
plt.ylabel('Review Rating')
# Out:
# Text(0, 0.5, 'Review Rating')

# %% [markdown]
# ### Polarity/Subjectivity Scatter Plot + Linear Regression

# %%
plt.scatter(sandiego_df['Sentiment'], sandiego_df['Subjectivity'])
plt.xlabel('Sentiment Score')
plt.ylabel('Subjectivity Score')
# Out:
# Text(0, 0.5, 'Subjectivity Score')

# %%
y_sub = sandiego_df['Subjectivity'].values.reshape(-1,1)

print("Shape:", X.shape, y_sub.shape)
# Out:
# Shape: (1444, 1) (1444, 1)

# %%
X_train_senti, X_test_senti, y_train_sub, y_test_sub = train_test_split(X, y_sub, random_state = 42)

# %%
sentimodel = LinearRegression()

# %%
sentimodel.fit(X_train_senti, y_train_sub)
# Out:
# LinearRegression()

# %%
sentimodel.score(X, y_sub)
# Out:
# 0.4534068379292464

# %%
senti_predict = sentimodel.predict(X_test_senti)

senti_mse = mean_squared_error(y_test_sub, senti_predict)
senti_r2 = r2_score(y_test_sub, senti_predict)

print(f'Mean Squared Error (MSE): {senti_mse}')
print (f'R-squared (R2): {senti_r2}')
# Out:
# Mean Squared Error (MSE): 0.0004705140711966779
# R-squared (R2): 0.46944067998858896

# %%
plt.scatter(X_test_senti, y_test_sub)
plt.plot(X_test_senti, senti_predict, color='red')
plt.xlabel('Sentiment Score')
plt.ylabel('Subjectivity Score')
# Out:
# Text(0, 0.5, 'Subjectivity Score')

# %% [markdown]
# As reviews become more opinionated, reviews tend to be more positive. Vice versa.
