# %%
import nltk 
import pandas as pd
from textblob import TextBlob
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords') #download stopwords 
from nltk.tokenize import word_tokenize
from nltk.stem import LancasterStemmer, WordNetLemmatizer, PorterStemmer

from sklearn.preprocessing import MinMaxScaler

import re 

stop_words = set(stopwords.words('english'))
suffix = PorterStemmer()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nagle.bagel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nagle.bagel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
review_text_df = pd.read_csv('data\\reviews.csv')

# %%
review_text_df.dropna(inplace = True)
review_text_df = review_text_df.groupby('listing_id').filter(lambda x: x['id'].count() > 100).reset_index(drop = True)
review_text_df['comments cleaned'] = review_text_df['comments'].apply(lambda x: " ".join(x.lower() for x in x.split()))
review_text_df['comments cleaned'] = review_text_df['comments cleaned'].str.replace(r'[^\w\s]','')
review_text_df['comments cleaned'] = review_text_df['comments cleaned'].apply(lambda x: " ".join(x for x in x.split() if x not in stop_words))
review_text_df['comments cleaned'] = review_text_df['comments cleaned'].apply(lambda x: " ".join([suffix.stem(word) for word in x.split()]))

review_text_df['tokens'] = review_text_df.apply(lambda row: word_tokenize(row['comments cleaned']), axis = 1)

# %%
review_text_df.head()
# Out:
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0       38245   93702  2010-09-09       187475       William
# 1       38245  132608  2010-11-02       269362          John
# 2       38245  142704  2010-11-22       108540         Suzan
# 3       38245  156426  2010-12-20       314129         Sonia
# 4       38245  169467  2011-01-11        25218         David
#
#                                             comments  \
# 0  really great hist and nice place, a good locat...
# 1  Melinda is a god person to deal with and very ...
# 2  Melinda's house in a beautiful part of San Die...
# 3  My stay at Melinda's was great. Such a nice, w...
# 4  Melinda is a very friendly host who is attenti...
#
#                                     comments cleaned  \
# 0  realli great hist nice place good locat san di...
# 1  melinda god person deal accommodatingeasi go h...
# 2  melinda hous beauti part san diego close airpo...
# 3  stay melinda great nice warm person beauti com...
# 4  melinda friendli host attent guest even invit ...
#
#                                               tokens
# 0  [realli, great, hist, nice, place, good, locat...
# 1  [melinda, god, person, deal, accommodatingeasi...
# 2  [melinda, hous, beauti, part, san, diego, clos...
# 3  [stay, melinda, great, nice, warm, person, bea...
# 4  [melinda, friendli, host, attent, guest, even,...

# %%
def sentimentFunc(x):
    return TextBlob(x).sentiment
#polarity is how positive -1 to 1, will scale to 0 to 1
#subjectivity is fact vs opinion, 0 to one, with factual being 0

# %%
review_text_df['senti'] = review_text_df['comments cleaned'].apply(sentimentFunc)
for index, row in review_text_df.iterrows():
    review_text_df.loc[index, 'Sentiment'], review_text_df.loc[index, 'Subjectivity'] = row['senti']

# %%
#review_text_df.to_csv('F:\\Important Folder\\School\\UCSD Extension Data Bootcamp\\final project\\project-3\\data\\separated_sentiment.csv')

# %%
review_text_df
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 0            38245      93702  2010-09-09       187475       William
# 1            38245     132608  2010-11-02       269362          John
# 2            38245     142704  2010-11-22       108540         Suzan
# 3            38245     156426  2010-12-20       314129         Sonia
# 4            38245     169467  2011-01-11        25218         David
# ...            ...        ...         ...          ...           ...
# 288419    43791368  735972757  2021-03-02     61179908          Chaz
# 288420    43791368  736287480  2021-03-04     56385941        Justin
# 288421    43791368  736545734  2021-03-05    152317017       Cameron
# 288422    43791368  739226692  2021-03-14    182841943         Gulya
# 288423    43791368  739928005  2021-03-17    392173895        Alyssa
#
#                                                  comments  \
# 0       really great hist and nice place, a good locat...
# 1       Melinda is a god person to deal with and very ...
# 2       Melinda's house in a beautiful part of San Die...
# 3       My stay at Melinda's was great. Such a nice, w...
# 4       Melinda is a very friendly host who is attenti...
# ...                                                   ...
# 288419  Great place to stay and only about a 5 minute ...
# 288420  Great spot. Exactly how described. Perfect for...
# 288421  The place was in a good location right downtow...
# 288422                              A nice place to stay!
# 288423  I would definitely never book with this host.\...
#
#                                          comments cleaned  \
# 0       realli great hist nice place good locat san di...
# 1       melinda god person deal accommodatingeasi go h...
# 2       melinda hous beauti part san diego close airpo...
# 3       stay melinda great nice warm person beauti com...
# 4       melinda friendli host attent guest even invit ...
# ...                                                   ...
# 288419  great place stay 5 minut drive airport car ren...
# 288420      great spot exactli describ perfect quick trip
# 288421  place good locat right downtown view bay one t...
# 288422                                    nice place stay
# 288423  would definit never book host unprofession sen...
#
#                                                    tokens  \
# 0       [realli, great, hist, nice, place, good, locat...
# 1       [melinda, god, person, deal, accommodatingeasi...
# 2       [melinda, hous, beauti, part, san, diego, clos...
# 3       [stay, melinda, great, nice, warm, person, bea...
# 4       [melinda, friendli, host, attent, guest, even,...
# ...                                                   ...
# 288419  [great, place, stay, 5, minut, drive, airport,...
# 288420  [great, spot, exactli, describ, perfect, quick...
# 288421  [place, good, locat, right, downtown, view, ba...
# 288422                                [nice, place, stay]
# 288423  [would, definit, never, book, host, unprofessi...
#
#                                             senti  Sentiment  Subjectivity
# 0         (0.3726190476190476, 0.686607142857143)   0.372619      0.686607
# 1                                      (0.0, 0.2)   0.000000      0.200000
# 2       (0.2285714285714286, 0.29523809523809524)   0.228571      0.295238
# 3        (0.5393939393939394, 0.7090909090909091)   0.539394      0.709091
# 4                                    (0.05, 0.25)   0.050000      0.250000
# ...                                           ...        ...           ...
# 288419               (0.35000000000000003, 0.425)   0.350000      0.425000
# 288420                 (0.7111111111111111, 0.75)   0.711111      0.750000
# 288421  (0.43605442176870746, 0.5086734693877552)   0.436054      0.508673
# 288422                                 (0.6, 1.0)   0.600000      1.000000
# 288423                              (-0.15, 0.65)  -0.150000      0.650000
#
# [288424 rows x 11 columns]

# %%
review_text_df = pd.read_csv('F:\\Important Folder\\School\\UCSD Extension Data Bootcamp\\final project\\project-3 - Copy\\data\\separated_sentiment.csv')

# %%
scaler = MinMaxScaler()

review_text_df['Sentiment'] = scaler.fit_transform(review_text_df[['Sentiment']])

# %%
listings = pd.read_csv('F:\\Important Folder\\School\\UCSD Extension Data Bootcamp\\final project\\project-3 - Copy\\data\\listings.csv')

# %%
listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   5570   https://www.airbnb.com/rooms/5570  20210317194010   2021-03-19
# 1  29967  https://www.airbnb.com/rooms/29967  20210317194010   2021-03-19
# 2  38245  https://www.airbnb.com/rooms/38245  20210317194010   2021-03-22
# 3  62274  https://www.airbnb.com/rooms/62274  20210317194010   2021-03-20
# 4  62949  https://www.airbnb.com/rooms/62949  20210317194010   2021-04-03
#
#                                                 name  \
# 0                      Ocean front condo on the sand
# 1                   Great home, 10 min walk to Beach
# 2                         Point Loma: Den downstairs
# 3                 charming, colorful, close to beach
# 4  Pacific Beach Cozy Private Hideaway Bikes Incl...
#
#                                          description  \
# 0  Missionbeachretreat.   Great Ocean Front Condo...
# 1  This 2 bedroom, 2 full bathroom home offers al...
# 2  Stay in a 1928 Spanish Style home.  Den is dow...
# 3  Modern, cozy, artsy, and european in a lush ga...
# 4  Wonderful Cozy Private Retreat. Included are u...
#
#                                neighborhood_overview  \
# 0  While some may compare San Diego’s Mission Bea...
# 1                                                NaN
# 2  This neighborhood is an expensive, high-end Po...
# 3  We are in walking distance to Starbucks, Trade...
# 4  This is the best part of Pacific Beach, we are...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/d3342744-140a...     8435
# 1  https://a0.muscache.com/pictures/76103867/c9b5...   129123
# 2  https://a0.muscache.com/pictures/f3073822-e493...   164137
# 3  https://a0.muscache.com/pictures/84577734/93ca...   302986
# 4  https://a0.muscache.com/pictures/f5d54435-d02a...    21532
#
#                                    host_url  ... review_scores_communication  \
# 0    https://www.airbnb.com/users/show/8435  ...                         NaN
# 1  https://www.airbnb.com/users/show/129123  ...                        10.0
# 2  https://www.airbnb.com/users/show/164137  ...                        10.0
# 3  https://www.airbnb.com/users/show/302986  ...                        10.0
# 4   https://www.airbnb.com/users/show/21532  ...                        10.0
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                    NaN                 NaN     NaN                f
# 1                   10.0                10.0     NaN                f
# 2                    9.0                 9.0     NaN                f
# 3                   10.0                10.0     NaN                f
# 4                   10.0                10.0     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              3                                           3
# 1                              5                                           5
# 2                              3                                           0
# 3                              2                                           2
# 4                              2                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            3
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0               NaN
# 1                                           0              0.48
# 2                                           0              1.11
# 3                                           0              5.05
# 4                                           0              7.17
#
# [5 rows x 74 columns]
